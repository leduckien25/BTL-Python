# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import sqlite3
import pandas as pd


driver = webdriver.Firefox()

url = "https://fbref.com/en/comps/9/2024-2025/2024-2025-Premier-League-Stats"
driver.get(url)

time.sleep(3)

html = driver.page_source
driver.quit()

soup = BeautifulSoup(html, "html.parser")

table = soup.find("table", id = "results2024-202591_overall")
tbody = table.find("tbody")

club_cells = tbody.find_all('tr')

club_links = []
for tr in club_cells:
    td = tr.find('td', attrs={'data-stat': 'team'})
    club_links.append('https://fbref.com' + td.a['href'])

club_links
# Out:
# ['https://fbref.com/en/squads/822bd0ba/2024-2025/Liverpool-Stats',
#  'https://fbref.com/en/squads/18bb7c10/2024-2025/Arsenal-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/2024-2025/Manchester-City-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/2024-2025/Chelsea-Stats',
#  'https://fbref.com/en/squads/b2b47a98/2024-2025/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/8602292d/2024-2025/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/e4a775cb/2024-2025/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/d07537b9/2024-2025/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/2024-2025/Bournemouth-Stats',
#  'https://fbref.com/en/squads/cd051869/2024-2025/Brentford-Stats',
#  'https://fbref.com/en/squads/fd962109/2024-2025/Fulham-Stats',
#  'https://fbref.com/en/squads/47c64c55/2024-2025/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/2024-2025/Everton-Stats',
#  'https://fbref.com/en/squads/7c21e445/2024-2025/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/19538871/2024-2025/Manchester-United-Stats',
#  'https://fbref.com/en/squads/8cec06e1/2024-2025/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/361ca564/2024-2025/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/a2d435b3/2024-2025/Leicester-City-Stats',
#  'https://fbref.com/en/squads/b74092de/2024-2025/Ipswich-Town-Stats',
#  'https://fbref.com/en/squads/33c895d4/2024-2025/Southampton-Stats']

# %%
driver = webdriver.Firefox()

players = []

for link in club_links:
    driver.get(link)
    time.sleep(3)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    table = soup.find('table', id='stats_standard_9')
    tbody = table.tbody

    current_player_cells = [tag for tag in tbody.find_all(
        'tr') if tag.get('class') is None]

    h1 = soup.h1.span.get_text()
    club = h1.replace('2024-2025', '').replace('Stats', '').strip()

    for cell in current_player_cells:

        player_dict = {}

        player_dict['player'] = cell.th.a.get_text().strip()
        player_dict['club'] = club

        for td in cell.find_all('td'):
            data_stat = td.get('data-stat')
            if data_stat == 'nationality':
                text = td.get_text()
                value = ''.join([c for c in text if c.isupper()])
            else:
                value = td.get_text().strip() if td.get_text().strip() else ''

            player_dict[data_stat] = value if value!='' else 'N/A'
        
        player_dict.pop('matches')

        minutes_text = player_dict.get('minutes', '0').replace(',', '')
        try:
            playing_time = int(minutes_text)
        except:
            playing_time = 0

        if playing_time > 90:
            player_dict['minutes'] = minutes_text
            players.append(player_dict)

driver.quit()

players
# Out:
# [{'player': 'Mohamed Salah',
#   'club': 'Liverpool',
#   'nationality': 'EGY',
#   'position': 'FW',
#   'age': '32',
#   'games': '38',
#   'games_starts': '38',
#   'minutes': '3371',
#   'minutes_90s': '37.5',
#   'goals': '29',
#   'assists': '18',
#   'goals_assists': '47',
#   'goals_pens': '20',
#   'pens_made': '9',
#   'pens_att': '9',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '25.2',
#   'npxg': '18.2',
#   'xg_assist': '14.2',
#   'npxg_xg_assist': '32.4',
#   'progressive_carries': '155',
#   'progressive_passes': '144',
#   'progressive_passes_received': '488',
#   'goals_per90': '0.77',
#   'assists_per90': '0.48',
#   'goals_assists_per90': '1.25',
#   'goals_pens_per90': '0.53',
#   'goals_assists_pens_per90': '1.01',
#   'xg_per90': '0.67',
#   'xg_assist_per90': '0.38',
#   'xg_xg_assist_per90': '1.05',
#   'npxg_per90': '0.49',
#   'npxg_xg_assist_per90': '0.87'},
#  {'player': 'Virgil van Dijk',
#   'club': 'Liverpool',
#   'nationality': 'NED',
#   'position': 'DF',
#   'age': '33',
#   'games': '37',
#   'games_starts': '37',
#   'minutes': '3330',
#   'minutes_90s': '37.0',
#   'goals': '3',
#   'assists': '1',
#   'goals_assists': '4',
#   'goals_pens': '3',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '2.2',
#   'npxg': '2.2',
#   'xg_assist': '0.7',
#   'npxg_xg_assist': '3.0',
#   'progressive_carries': '22',
#   'progressive_passes': '198',
#   'progressive_passes_received': '6',
#   'goals_per90': '0.08',
#   'assists_per90': '0.03',
#   'goals_assists_per90': '0.11',
#   'goals_pens_per90': '0.08',
#   'goals_assists_pens_per90': '0.11',
#   'xg_per90': '0.06',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.06',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Ryan Gravenberch',
#   'club': 'Liverpool',
#   'nationality': 'NED',
#   'position': 'MF',
#   'age': '22',
#   'games': '37',
#   'games_starts': '37',
#   'minutes': '3160',
#   'minutes_90s': '35.1',
#   'goals': '0',
#   'assists': '4',
#   'goals_assists': '4',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '6',
#   'cards_red': '1',
#   'xg': '1.1',
#   'npxg': '1.1',
#   'xg_assist': '3.1',
#   'npxg_xg_assist': '4.2',
#   'progressive_carries': '70',
#   'progressive_passes': '181',
#   'progressive_passes_received': '55',
#   'goals_per90': '0.00',
#   'assists_per90': '0.11',
#   'goals_assists_per90': '0.11',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.11',
#   'xg_per90': '0.03',
#   'xg_assist_per90': '0.09',
#   'xg_xg_assist_per90': '0.12',
#   'npxg_per90': '0.03',
#   'npxg_xg_assist_per90': '0.12'},
#  {'player': 'Alexis Mac Allister',
#   'club': 'Liverpool',
#   'nationality': 'ARG',
#   'position': 'MF',
#   'age': '25',
#   'games': '35',
#   'games_starts': '30',
#   'minutes': '2599',
#   'minutes_90s': '28.9',
#   'goals': '5',
#   'assists': '5',
#   'goals_assists': '10',
#   'goals_pens': '5',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '6',
#   'cards_red': '0',
#   'xg': '2.8',
#   'npxg': '2.8',
#   'xg_assist': '4.7',
#   'npxg_xg_assist': '7.5',
#   'progressive_carries': '36',
#   'progressive_passes': '177',
#   'progressive_passes_received': '80',
#   'goals_per90': '0.17',
#   'assists_per90': '0.17',
#   'goals_assists_per90': '0.35',
#   'goals_pens_per90': '0.17',
#   'goals_assists_pens_per90': '0.35',
#   'xg_per90': '0.10',
#   'xg_assist_per90': '0.16',
#   'xg_xg_assist_per90': '0.26',
#   'npxg_per90': '0.10',
#   'npxg_xg_assist_per90': '0.26'},
#  {'player': 'Ibrahima Konaté',
#   'club': 'Liverpool',
#   'nationality': 'FRA',
#   'position': 'DF',
#   'age': '25',
#   'games': '31',
#   'games_starts': '30',
#   'minutes': '2560',
#   'minutes_90s': '28.4',
#   'goals': '1',
#   'assists': '2',
#   'goals_assists': '3',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '1.7',
#   'npxg': '1.7',
#   'xg_assist': '1.0',
#   'npxg_xg_assist': '2.7',
#   'progressive_carries': '25',
#   'progressive_passes': '115',
#   'progressive_passes_received': '3',
#   'goals_per90': '0.04',
#   'assists_per90': '0.07',
#   'goals_assists_per90': '0.11',
#   'goals_pens_per90': '0.04',
#   'goals_assists_pens_per90': '0.11',
#   'xg_per90': '0.06',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.10',
#   'npxg_per90': '0.06',
#   'npxg_xg_assist_per90': '0.10'},
#  {'player': 'Dominik Szoboszlai',
#   'club': 'Liverpool',
#   'nationality': 'HUN',
#   'position': 'MF',
#   'age': '23',
#   'games': '36',
#   'games_starts': '29',
#   'minutes': '2491',
#   'minutes_90s': '27.7',
#   'goals': '6',
#   'assists': '6',
#   'goals_assists': '12',
#   'goals_pens': '6',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '6',
#   'cards_red': '0',
#   'xg': '7.3',
#   'npxg': '7.3',
#   'xg_assist': '7.4',
#   'npxg_xg_assist': '14.7',
#   'progressive_carries': '72',
#   'progressive_passes': '131',
#   'progressive_passes_received': '127',
#   'goals_per90': '0.22',
#   'assists_per90': '0.22',
#   'goals_assists_per90': '0.43',
#   'goals_pens_per90': '0.22',
#   'goals_assists_pens_per90': '0.43',
#   'xg_per90': '0.27',
#   'xg_assist_per90': '0.27',
#   'xg_xg_assist_per90': '0.53',
#   'npxg_per90': '0.27',
#   'npxg_xg_assist_per90': '0.53'},
#  {'player': 'Andrew Robertson',
#   'club': 'Liverpool',
#   'nationality': 'SCO',
#   'position': 'DF',
#   'age': '30',
#   'games': '33',
#   'games_starts': '29',
#   'minutes': '2482',
#   'minutes_90s': '27.6',
#   'goals': '0',
#   'assists': '1',
#   'goals_assists': '1',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '1',
#   'xg': '1.2',
#   'npxg': '1.2',
#   'xg_assist': '4.6',
#   'npxg_xg_assist': '5.8',
#   'progressive_carries': '64',
#   'progressive_passes': '176',
#   'progressive_passes_received': '108',
#   'goals_per90': '0.00',
#   'assists_per90': '0.04',
#   'goals_assists_per90': '0.04',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.04',
#   'xg_per90': '0.04',
#   'xg_assist_per90': '0.17',
#   'xg_xg_assist_per90': '0.21',
#   'npxg_per90': '0.04',
#   'npxg_xg_assist_per90': '0.21'},
#  {'player': 'Alisson',
#   'club': 'Liverpool',
#   'nationality': 'BRA',
#   'position': 'GK',
#   'age': '31',
#   'games': '28',
#   'games_starts': '28',
#   'minutes': '2508',
#   'minutes_90s': '27.9',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.6',
#   'npxg_xg_assist': '0.6',
#   'progressive_carries': '0',
#   'progressive_passes': '1',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.02',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.02'},
#  {'player': 'Luis Díaz',
#   'club': 'Liverpool',
#   'nationality': 'COL',
#   'position': 'FW',
#   'age': '27',
#   'games': '36',
#   'games_starts': '28',
#   'minutes': '2399',
#   'minutes_90s': '26.7',
#   'goals': '13',
#   'assists': '5',
#   'goals_assists': '18',
#   'goals_pens': '13',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '12.0',
#   'npxg': '12.0',
#   'xg_assist': '5.0',
#   'npxg_xg_assist': '17.1',
#   'progressive_carries': '108',
#   'progressive_passes': '110',
#   'progressive_passes_received': '293',
#   'goals_per90': '0.49',
#   'assists_per90': '0.19',
#   'goals_assists_per90': '0.68',
#   'goals_pens_per90': '0.49',
#   'goals_assists_pens_per90': '0.68',
#   'xg_per90': '0.45',
#   'xg_assist_per90': '0.19',
#   'xg_xg_assist_per90': '0.64',
#   'npxg_per90': '0.45',
#   'npxg_xg_assist_per90': '0.64'},
#  {'player': 'Trent Alexander-Arnold',
#   'club': 'Liverpool',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '25',
#   'games': '33',
#   'games_starts': '28',
#   'minutes': '2365',
#   'minutes_90s': '26.3',
#   'goals': '3',
#   'assists': '6',
#   'goals_assists': '9',
#   'goals_pens': '3',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '1.9',
#   'npxg': '1.9',
#   'xg_assist': '7.3',
#   'npxg_xg_assist': '9.2',
#   'progressive_carries': '51',
#   'progressive_passes': '232',
#   'progressive_passes_received': '94',
#   'goals_per90': '0.11',
#   'assists_per90': '0.23',
#   'goals_assists_per90': '0.34',
#   'goals_pens_per90': '0.11',
#   'goals_assists_pens_per90': '0.34',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.28',
#   'xg_xg_assist_per90': '0.35',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.35'},
#  {'player': 'Cody Gakpo',
#   'club': 'Liverpool',
#   'nationality': 'NED',
#   'position': 'FW',
#   'age': '25',
#   'games': '35',
#   'games_starts': '23',
#   'minutes': '1935',
#   'minutes_90s': '21.5',
#   'goals': '10',
#   'assists': '4',
#   'goals_assists': '14',
#   'goals_pens': '10',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '7.1',
#   'npxg': '7.1',
#   'xg_assist': '4.4',
#   'npxg_xg_assist': '11.5',
#   'progressive_carries': '59',
#   'progressive_passes': '52',
#   'progressive_passes_received': '278',
#   'goals_per90': '0.47',
#   'assists_per90': '0.19',
#   'goals_assists_per90': '0.65',
#   'goals_pens_per90': '0.47',
#   'goals_assists_pens_per90': '0.65',
#   'xg_per90': '0.33',
#   'xg_assist_per90': '0.20',
#   'xg_xg_assist_per90': '0.53',
#   'npxg_per90': '0.33',
#   'npxg_xg_assist_per90': '0.53'},
#  {'player': 'Curtis Jones',
#   'club': 'Liverpool',
#   'nationality': 'ENG',
#   'position': 'MF,DF',
#   'age': '23',
#   'games': '33',
#   'games_starts': '19',
#   'minutes': '1712',
#   'minutes_90s': '19.0',
#   'goals': '3',
#   'assists': '3',
#   'goals_assists': '6',
#   'goals_pens': '3',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '1',
#   'xg': '4.3',
#   'npxg': '4.3',
#   'xg_assist': '1.1',
#   'npxg_xg_assist': '5.4',
#   'progressive_carries': '30',
#   'progressive_passes': '117',
#   'progressive_passes_received': '79',
#   'goals_per90': '0.16',
#   'assists_per90': '0.16',
#   'goals_assists_per90': '0.32',
#   'goals_pens_per90': '0.16',
#   'goals_assists_pens_per90': '0.32',
#   'xg_per90': '0.23',
#   'xg_assist_per90': '0.06',
#   'xg_xg_assist_per90': '0.29',
#   'npxg_per90': '0.23',
#   'npxg_xg_assist_per90': '0.29'},
#  {'player': 'Diogo Jota',
#   'club': 'Liverpool',
#   'nationality': 'POR',
#   'position': 'FW',
#   'age': '27',
#   'games': '26',
#   'games_starts': '14',
#   'minutes': '1196',
#   'minutes_90s': '13.3',
#   'goals': '6',
#   'assists': '3',
#   'goals_assists': '9',
#   'goals_pens': '6',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '7.9',
#   'npxg': '7.9',
#   'xg_assist': '1.8',
#   'npxg_xg_assist': '9.8',
#   'progressive_carries': '37',
#   'progressive_passes': '34',
#   'progressive_passes_received': '88',
#   'goals_per90': '0.45',
#   'assists_per90': '0.23',
#   'goals_assists_per90': '0.68',
#   'goals_pens_per90': '0.45',
#   'goals_assists_pens_per90': '0.68',
#   'xg_per90': '0.60',
#   'xg_assist_per90': '0.14',
#   'xg_xg_assist_per90': '0.74',
#   'npxg_per90': '0.60',
#   'npxg_xg_assist_per90': '0.74'},
#  {'player': 'Caoimhín Kelleher',
#   'club': 'Liverpool',
#   'nationality': 'IRL',
#   'position': 'GK',
#   'age': '25',
#   'games': '10',
#   'games_starts': '10',
#   'minutes': '900',
#   'minutes_90s': '10.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.0',
#   'progressive_carries': '0',
#   'progressive_passes': '0',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.00',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.00'},
#  {'player': 'Kostas Tsimikas',
#   'club': 'Liverpool',
#   'nationality': 'GRE',
#   'position': 'DF',
#   'age': '28',
#   'games': '18',
#   'games_starts': '9',
#   'minutes': '837',
#   'minutes_90s': '9.3',
#   'goals': '0',
#   'assists': '1',
#   'goals_assists': '1',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '0.4',
#   'npxg': '0.4',
#   'xg_assist': '2.1',
#   'npxg_xg_assist': '2.5',
#   'progressive_carries': '17',
#   'progressive_passes': '76',
#   'progressive_passes_received': '43',
#   'goals_per90': '0.00',
#   'assists_per90': '0.11',
#   'goals_assists_per90': '0.11',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.11',
#   'xg_per90': '0.04',
#   'xg_assist_per90': '0.23',
#   'xg_xg_assist_per90': '0.27',
#   'npxg_per90': '0.04',
#   'npxg_xg_assist_per90': '0.27'},
#  {'player': 'Darwin Núñez',
#   'club': 'Liverpool',
#   'nationality': 'URU',
#   'position': 'FW',
#   'age': '25',
#   'games': '30',
#   'games_starts': '8',
#   'minutes': '1133',
#   'minutes_90s': '12.6',
#   'goals': '5',
#   'assists': '2',
#   'goals_assists': '7',
#   'goals_pens': '5',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '8',
#   'cards_red': '0',
#   'xg': '5.8',
#   'npxg': '5.8',
#   'xg_assist': '1.3',
#   'npxg_xg_assist': '7.1',
#   'progressive_carries': '23',
#   'progressive_passes': '27',
#   'progressive_passes_received': '78',
#   'goals_per90': '0.40',
#   'assists_per90': '0.16',
#   'goals_assists_per90': '0.56',
#   'goals_pens_per90': '0.40',
#   'goals_assists_pens_per90': '0.56',
#   'xg_per90': '0.46',
#   'xg_assist_per90': '0.10',
#   'xg_xg_assist_per90': '0.57',
#   'npxg_per90': '0.46',
#   'npxg_xg_assist_per90': '0.57'},
#  {'player': 'Conor Bradley',
#   'club': 'Liverpool',
#   'nationality': 'NIR',
#   'position': 'DF',
#   'age': '21',
#   'games': '19',
#   'games_starts': '7',
#   'minutes': '754',
#   'minutes_90s': '8.4',
#   'goals': '0',
#   'assists': '2',
#   'goals_assists': '2',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '0.7',
#   'npxg': '0.7',
#   'xg_assist': '1.4',
#   'npxg_xg_assist': '2.1',
#   'progressive_carries': '35',
#   'progressive_passes': '33',
#   'progressive_passes_received': '39',
#   'goals_per90': '0.00',
#   'assists_per90': '0.24',
#   'goals_assists_per90': '0.24',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.24',
#   'xg_per90': '0.08',
#   'xg_assist_per90': '0.17',
#   'xg_xg_assist_per90': '0.25',
#   'npxg_per90': '0.08',
#   'npxg_xg_assist_per90': '0.25'},
#  {'player': 'Joe Gomez',
#   'club': 'Liverpool',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '27',
#   'games': '9',
#   'games_starts': '6',
#   'minutes': '519',
#   'minutes_90s': '5.8',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.3',
#   'npxg': '0.3',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.4',
#   'progressive_carries': '5',
#   'progressive_passes': '35',
#   'progressive_passes_received': '2',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.06',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.06',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Jarell Quansah',
#   'club': 'Liverpool',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '21',
#   'games': '13',
#   'games_starts': '4',
#   'minutes': '495',
#   'minutes_90s': '5.5',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '0.1',
#   'npxg': '0.1',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.2',
#   'progressive_carries': '3',
#   'progressive_passes': '19',
#   'progressive_passes_received': '4',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.02',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.04',
#   'npxg_per90': '0.02',
#   'npxg_xg_assist_per90': '0.04'},
#  {'player': 'Harvey Elliott',
#   'club': 'Liverpool',
#   'nationality': 'ENG',
#   'position': 'MF',
#   'age': '21',
#   'games': '18',
#   'games_starts': '2',
#   'minutes': '371',
#   'minutes_90s': '4.1',
#   'goals': '1',
#   'assists': '2',
#   'goals_assists': '3',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '1.8',
#   'npxg': '1.8',
#   'xg_assist': '1.1',
#   'npxg_xg_assist': '2.8',
#   'progressive_carries': '10',
#   'progressive_passes': '44',
#   'progressive_passes_received': '30',
#   'goals_per90': '0.24',
#   'assists_per90': '0.49',
#   'goals_assists_per90': '0.73',
#   'goals_pens_per90': '0.24',
#   'goals_assists_pens_per90': '0.73',
#   'xg_per90': '0.43',
#   'xg_assist_per90': '0.26',
#   'xg_xg_assist_per90': '0.69',
#   'npxg_per90': '0.43',
#   'npxg_xg_assist_per90': '0.69'},
#  {'player': 'Wataru Endo',
#   'club': 'Liverpool',
#   'nationality': 'JPN',
#   'position': 'MF,DF',
#   'age': '31',
#   'games': '20',
#   'games_starts': '1',
#   'minutes': '273',
#   'minutes_90s': '3.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.1',
#   'progressive_carries': '1',
#   'progressive_passes': '19',
#   'progressive_passes_received': '8',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.02',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.02'},
#  {'player': 'Federico Chiesa',
#   'club': 'Liverpool',
#   'nationality': 'ITA',
#   'position': 'FW',
#   'age': '26',
#   'games': '6',
#   'games_starts': '1',
#   'minutes': '108',
#   'minutes_90s': '1.2',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.3',
#   'npxg': '0.3',
#   'xg_assist': '0.2',
#   'npxg_xg_assist': '0.5',
#   'progressive_carries': '3',
#   'progressive_passes': '3',
#   'progressive_passes_received': '7',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.28',
#   'xg_assist_per90': '0.15',
#   'xg_xg_assist_per90': '0.43',
#   'npxg_per90': '0.28',
#   'npxg_xg_assist_per90': '0.43'},
#  {'player': 'David Raya',
#   'club': 'Arsenal',
#   'nationality': 'ESP',
#   'position': 'GK',
#   'age': '28',
#   'games': '38',
#   'games_starts': '38',
#   'minutes': '3420',
#   'minutes_90s': '38.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.0',
#   'progressive_carries': '0',
#   'progressive_passes': '14',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.00',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.00'},
#  {'player': 'William Saliba',
#   'club': 'Arsenal',
#   'nationality': 'FRA',
#   'position': 'DF',
#   'age': '23',
#   'games': '35',
#   'games_starts': '35',
#   'minutes': '3039',
#   'minutes_90s': '33.8',
#   'goals': '2',
#   'assists': '0',
#   'goals_assists': '2',
#   'goals_pens': '2',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '1',
#   'xg': '2.3',
#   'npxg': '2.3',
#   'xg_assist': '0.9',
#   'npxg_xg_assist': '3.1',
#   'progressive_carries': '16',
#   'progressive_passes': '138',
#   'progressive_passes_received': '6',
#   'goals_per90': '0.06',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.06',
#   'goals_pens_per90': '0.06',
#   'goals_assists_pens_per90': '0.06',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.09',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.09'},
#  {'player': 'Declan Rice',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'MF',
#   'age': '25',
#   'games': '35',
#   'games_starts': '33',
#   'minutes': '2825',
#   'minutes_90s': '31.4',
#   'goals': '4',
#   'assists': '7',
#   'goals_assists': '11',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '7',
#   'cards_red': '1',
#   'xg': '3.5',
#   'npxg': '3.5',
#   'xg_assist': '6.6',
#   'npxg_xg_assist': '10.1',
#   'progressive_carries': '90',
#   'progressive_passes': '192',
#   'progressive_passes_received': '94',
#   'goals_per90': '0.13',
#   'assists_per90': '0.22',
#   'goals_assists_per90': '0.35',
#   'goals_pens_per90': '0.13',
#   'goals_assists_pens_per90': '0.35',
#   'xg_per90': '0.11',
#   'xg_assist_per90': '0.21',
#   'xg_xg_assist_per90': '0.32',
#   'npxg_per90': '0.11',
#   'npxg_xg_assist_per90': '0.32'},
#  {'player': 'Thomas Partey',
#   'club': 'Arsenal',
#   'nationality': 'GHA',
#   'position': 'MF,DF',
#   'age': '31',
#   'games': '35',
#   'games_starts': '31',
#   'minutes': '2797',
#   'minutes_90s': '31.1',
#   'goals': '4',
#   'assists': '2',
#   'goals_assists': '6',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '2.3',
#   'npxg': '2.3',
#   'xg_assist': '2.1',
#   'npxg_xg_assist': '4.3',
#   'progressive_carries': '36',
#   'progressive_passes': '185',
#   'progressive_passes_received': '48',
#   'goals_per90': '0.13',
#   'assists_per90': '0.06',
#   'goals_assists_per90': '0.19',
#   'goals_pens_per90': '0.13',
#   'goals_assists_pens_per90': '0.19',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.07',
#   'xg_xg_assist_per90': '0.14',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.14'},
#  {'player': 'Leandro Trossard',
#   'club': 'Arsenal',
#   'nationality': 'BEL',
#   'position': 'FW',
#   'age': '29',
#   'games': '38',
#   'games_starts': '28',
#   'minutes': '2546',
#   'minutes_90s': '28.3',
#   'goals': '8',
#   'assists': '7',
#   'goals_assists': '15',
#   'goals_pens': '8',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '1',
#   'xg': '7.2',
#   'npxg': '7.2',
#   'xg_assist': '6.1',
#   'npxg_xg_assist': '13.3',
#   'progressive_carries': '80',
#   'progressive_passes': '101',
#   'progressive_passes_received': '226',
#   'goals_per90': '0.28',
#   'assists_per90': '0.25',
#   'goals_assists_per90': '0.53',
#   'goals_pens_per90': '0.28',
#   'goals_assists_pens_per90': '0.53',
#   'xg_per90': '0.25',
#   'xg_assist_per90': '0.22',
#   'xg_xg_assist_per90': '0.47',
#   'npxg_per90': '0.25',
#   'npxg_xg_assist_per90': '0.47'},
#  {'player': 'Gabriel Magalhães',
#   'club': 'Arsenal',
#   'nationality': 'BRA',
#   'position': 'DF',
#   'age': '26',
#   'games': '28',
#   'games_starts': '28',
#   'minutes': '2363',
#   'minutes_90s': '26.3',
#   'goals': '3',
#   'assists': '1',
#   'goals_assists': '4',
#   'goals_pens': '3',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '2.6',
#   'npxg': '2.6',
#   'xg_assist': '0.9',
#   'npxg_xg_assist': '3.5',
#   'progressive_carries': '10',
#   'progressive_passes': '126',
#   'progressive_passes_received': '11',
#   'goals_per90': '0.11',
#   'assists_per90': '0.04',
#   'goals_assists_per90': '0.15',
#   'goals_pens_per90': '0.11',
#   'goals_assists_pens_per90': '0.15',
#   'xg_per90': '0.10',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.13',
#   'npxg_per90': '0.10',
#   'npxg_xg_assist_per90': '0.13'},
#  {'player': 'Jurriën Timber',
#   'club': 'Arsenal',
#   'nationality': 'NED',
#   'position': 'DF',
#   'age': '23',
#   'games': '30',
#   'games_starts': '27',
#   'minutes': '2417',
#   'minutes_90s': '26.9',
#   'goals': '1',
#   'assists': '3',
#   'goals_assists': '4',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '7',
#   'cards_red': '0',
#   'xg': '1.2',
#   'npxg': '1.2',
#   'xg_assist': '0.8',
#   'npxg_xg_assist': '2.1',
#   'progressive_carries': '57',
#   'progressive_passes': '146',
#   'progressive_passes_received': '104',
#   'goals_per90': '0.04',
#   'assists_per90': '0.11',
#   'goals_assists_per90': '0.15',
#   'goals_pens_per90': '0.04',
#   'goals_assists_pens_per90': '0.15',
#   'xg_per90': '0.05',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.05',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Martin Ødegaard',
#   'club': 'Arsenal',
#   'nationality': 'NOR',
#   'position': 'MF',
#   'age': '25',
#   'games': '30',
#   'games_starts': '26',
#   'minutes': '2325',
#   'minutes_90s': '25.8',
#   'goals': '3',
#   'assists': '8',
#   'goals_assists': '11',
#   'goals_pens': '2',
#   'pens_made': '1',
#   'pens_att': '1',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '4.8',
#   'npxg': '4.0',
#   'xg_assist': '5.4',
#   'npxg_xg_assist': '9.5',
#   'progressive_carries': '92',
#   'progressive_passes': '258',
#   'progressive_passes_received': '154',
#   'goals_per90': '0.12',
#   'assists_per90': '0.31',
#   'goals_assists_per90': '0.43',
#   'goals_pens_per90': '0.08',
#   'goals_assists_pens_per90': '0.39',
#   'xg_per90': '0.19',
#   'xg_assist_per90': '0.21',
#   'xg_xg_assist_per90': '0.40',
#   'npxg_per90': '0.16',
#   'npxg_xg_assist_per90': '0.37'},
#  {'player': 'Gabriel Martinelli',
#   'club': 'Arsenal',
#   'nationality': 'BRA',
#   'position': 'FW,MF',
#   'age': '23',
#   'games': '33',
#   'games_starts': '25',
#   'minutes': '2290',
#   'minutes_90s': '25.4',
#   'goals': '8',
#   'assists': '4',
#   'goals_assists': '12',
#   'goals_pens': '8',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '7.4',
#   'npxg': '7.4',
#   'xg_assist': '5.0',
#   'npxg_xg_assist': '12.4',
#   'progressive_carries': '124',
#   'progressive_passes': '52',
#   'progressive_passes_received': '289',
#   'goals_per90': '0.31',
#   'assists_per90': '0.16',
#   'goals_assists_per90': '0.47',
#   'goals_pens_per90': '0.31',
#   'goals_assists_pens_per90': '0.47',
#   'xg_per90': '0.29',
#   'xg_assist_per90': '0.19',
#   'xg_xg_assist_per90': '0.49',
#   'npxg_per90': '0.29',
#   'npxg_xg_assist_per90': '0.49'},
#  {'player': 'Kai Havertz',
#   'club': 'Arsenal',
#   'nationality': 'GER',
#   'position': 'FW,MF',
#   'age': '25',
#   'games': '23',
#   'games_starts': '21',
#   'minutes': '1875',
#   'minutes_90s': '20.8',
#   'goals': '9',
#   'assists': '3',
#   'goals_assists': '12',
#   'goals_pens': '9',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '9.5',
#   'npxg': '9.5',
#   'xg_assist': '2.4',
#   'npxg_xg_assist': '12.0',
#   'progressive_carries': '35',
#   'progressive_passes': '61',
#   'progressive_passes_received': '113',
#   'goals_per90': '0.43',
#   'assists_per90': '0.14',
#   'goals_assists_per90': '0.58',
#   'goals_pens_per90': '0.43',
#   'goals_assists_pens_per90': '0.58',
#   'xg_per90': '0.46',
#   'xg_assist_per90': '0.12',
#   'xg_xg_assist_per90': '0.57',
#   'npxg_per90': '0.46',
#   'npxg_xg_assist_per90': '0.57'},
#  {'player': 'Bukayo Saka',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'FW,MF',
#   'age': '22',
#   'games': '25',
#   'games_starts': '20',
#   'minutes': '1729',
#   'minutes_90s': '19.2',
#   'goals': '6',
#   'assists': '10',
#   'goals_assists': '16',
#   'goals_pens': '5',
#   'pens_made': '1',
#   'pens_att': '1',
#   'cards_yellow': '3',
#   'cards_red': '0',
#   'xg': '6.8',
#   'npxg': '6.0',
#   'xg_assist': '7.6',
#   'npxg_xg_assist': '13.7',
#   'progressive_carries': '96',
#   'progressive_passes': '70',
#   'progressive_passes_received': '255',
#   'goals_per90': '0.31',
#   'assists_per90': '0.52',
#   'goals_assists_per90': '0.83',
#   'goals_pens_per90': '0.26',
#   'goals_assists_pens_per90': '0.78',
#   'xg_per90': '0.36',
#   'xg_assist_per90': '0.40',
#   'xg_xg_assist_per90': '0.75',
#   'npxg_per90': '0.31',
#   'npxg_xg_assist_per90': '0.71'},
#  {'player': 'Mikel Merino',
#   'club': 'Arsenal',
#   'nationality': 'ESP',
#   'position': 'MF,FW',
#   'age': '28',
#   'games': '28',
#   'games_starts': '17',
#   'minutes': '1586',
#   'minutes_90s': '17.6',
#   'goals': '7',
#   'assists': '2',
#   'goals_assists': '9',
#   'goals_pens': '7',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '1',
#   'xg': '5.9',
#   'npxg': '5.9',
#   'xg_assist': '2.0',
#   'npxg_xg_assist': '7.9',
#   'progressive_carries': '11',
#   'progressive_passes': '69',
#   'progressive_passes_received': '94',
#   'goals_per90': '0.40',
#   'assists_per90': '0.11',
#   'goals_assists_per90': '0.51',
#   'goals_pens_per90': '0.40',
#   'goals_assists_pens_per90': '0.51',
#   'xg_per90': '0.34',
#   'xg_assist_per90': '0.11',
#   'xg_xg_assist_per90': '0.45',
#   'npxg_per90': '0.34',
#   'npxg_xg_assist_per90': '0.45'},
#  {'player': 'Myles Lewis-Skelly',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '17',
#   'games': '23',
#   'games_starts': '15',
#   'minutes': '1369',
#   'minutes_90s': '15.2',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '2',
#   'xg': '0.2',
#   'npxg': '0.2',
#   'xg_assist': '0.4',
#   'npxg_xg_assist': '0.6',
#   'progressive_carries': '37',
#   'progressive_passes': '71',
#   'progressive_passes_received': '37',
#   'goals_per90': '0.07',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.07',
#   'goals_pens_per90': '0.07',
#   'goals_assists_pens_per90': '0.07',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.04',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.04'},
#  {'player': 'Ben White',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '26',
#   'games': '17',
#   'games_starts': '13',
#   'minutes': '1198',
#   'minutes_90s': '13.3',
#   'goals': '0',
#   'assists': '2',
#   'goals_assists': '2',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '0.5',
#   'npxg': '0.5',
#   'xg_assist': '1.4',
#   'npxg_xg_assist': '1.8',
#   'progressive_carries': '23',
#   'progressive_passes': '59',
#   'progressive_passes_received': '42',
#   'goals_per90': '0.00',
#   'assists_per90': '0.15',
#   'goals_assists_per90': '0.15',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.15',
#   'xg_per90': '0.03',
#   'xg_assist_per90': '0.10',
#   'xg_xg_assist_per90': '0.14',
#   'npxg_per90': '0.03',
#   'npxg_xg_assist_per90': '0.14'},
#  {'player': 'Riccardo Calafiori',
#   'club': 'Arsenal',
#   'nationality': 'ITA',
#   'position': 'DF',
#   'age': '22',
#   'games': '19',
#   'games_starts': '11',
#   'minutes': '983',
#   'minutes_90s': '10.9',
#   'goals': '2',
#   'assists': '1',
#   'goals_assists': '3',
#   'goals_pens': '2',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '0.9',
#   'npxg': '0.9',
#   'xg_assist': '0.3',
#   'npxg_xg_assist': '1.1',
#   'progressive_carries': '22',
#   'progressive_passes': '54',
#   'progressive_passes_received': '29',
#   'goals_per90': '0.18',
#   'assists_per90': '0.09',
#   'goals_assists_per90': '0.27',
#   'goals_pens_per90': '0.18',
#   'goals_assists_pens_per90': '0.27',
#   'xg_per90': '0.08',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.11',
#   'npxg_per90': '0.08',
#   'npxg_xg_assist_per90': '0.11'},
#  {'player': 'Ethan Nwaneri',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'FW,MF',
#   'age': '17',
#   'games': '26',
#   'games_starts': '11',
#   'minutes': '895',
#   'minutes_90s': '9.9',
#   'goals': '4',
#   'assists': '2',
#   'goals_assists': '6',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '1.2',
#   'npxg': '1.2',
#   'xg_assist': '1.2',
#   'npxg_xg_assist': '2.4',
#   'progressive_carries': '46',
#   'progressive_passes': '33',
#   'progressive_passes_received': '113',
#   'goals_per90': '0.40',
#   'assists_per90': '0.20',
#   'goals_assists_per90': '0.60',
#   'goals_pens_per90': '0.40',
#   'goals_assists_pens_per90': '0.60',
#   'xg_per90': '0.12',
#   'xg_assist_per90': '0.12',
#   'xg_xg_assist_per90': '0.24',
#   'npxg_per90': '0.12',
#   'npxg_xg_assist_per90': '0.24'},
#  {'player': 'Jakub Kiwior',
#   'club': 'Arsenal',
#   'nationality': 'POL',
#   'position': 'DF',
#   'age': '24',
#   'games': '17',
#   'games_starts': '10',
#   'minutes': '1122',
#   'minutes_90s': '12.5',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.2',
#   'npxg': '0.2',
#   'xg_assist': '0.3',
#   'npxg_xg_assist': '0.5',
#   'progressive_carries': '5',
#   'progressive_passes': '48',
#   'progressive_passes_received': '1',
#   'goals_per90': '0.08',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.08',
#   'goals_pens_per90': '0.08',
#   'goals_assists_pens_per90': '0.08',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.04',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.04'},
#  {'player': 'Jorginho',
#   'club': 'Arsenal',
#   'nationality': 'ITA',
#   'position': 'MF',
#   'age': '32',
#   'games': '15',
#   'games_starts': '9',
#   'minutes': '704',
#   'minutes_90s': '7.8',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '0',
#   'xg': '0.1',
#   'npxg': '0.1',
#   'xg_assist': '0.4',
#   'npxg_xg_assist': '0.5',
#   'progressive_carries': '12',
#   'progressive_passes': '48',
#   'progressive_passes_received': '6',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.05',
#   'xg_xg_assist_per90': '0.06',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.06'},
#  {'player': 'Raheem Sterling',
#   'club': 'Arsenal',
#   'nationality': 'ENG',
#   'position': 'FW,MF',
#   'age': '29',
#   'games': '17',
#   'games_starts': '7',
#   'minutes': '499',
#   'minutes_90s': '5.5',
#   'goals': '0',
#   'assists': '2',
#   'goals_assists': '2',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '1.4',
#   'npxg': '1.4',
#   'xg_assist': '0.5',
#   'npxg_xg_assist': '1.9',
#   'progressive_carries': '27',
#   'progressive_passes': '18',
#   'progressive_passes_received': '79',
#   'goals_per90': '0.00',
#   'assists_per90': '0.36',
#   'goals_assists_per90': '0.36',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.36',
#   'xg_per90': '0.26',
#   'xg_assist_per90': '0.09',
#   'xg_xg_assist_per90': '0.34',
#   'npxg_per90': '0.26',
#   'npxg_xg_assist_per90': '0.34'},
#  {'player': 'Gabriel Jesus',
#   'club': 'Arsenal',
#   'nationality': 'BRA',
#   'position': 'FW',
#   'age': '27',
#   'games': '17',
#   'games_starts': '6',
#   'minutes': '608',
#   'minutes_90s': '6.8',
#   'goals': '3',
#   'assists': '0',
#   'goals_assists': '3',
#   'goals_pens': '3',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '3.0',
#   'npxg': '3.0',
#   'xg_assist': '0.7',
#   'npxg_xg_assist': '3.7',
#   'progressive_carries': '15',
#   'progressive_passes': '19',
#   'progressive_passes_received': '57',
#   'goals_per90': '0.44',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.44',
#   'goals_pens_per90': '0.44',
#   'goals_assists_pens_per90': '0.44',
#   'xg_per90': '0.44',
#   'xg_assist_per90': '0.10',
#   'xg_xg_assist_per90': '0.54',
#   'npxg_per90': '0.44',
#   'npxg_xg_assist_per90': '0.54'},
#  {'player': 'Oleksandr Zinchenko',
#   'club': 'Arsenal',
#   'nationality': 'UKR',
#   'position': 'DF,MF',
#   'age': '27',
#   'games': '15',
#   'games_starts': '5',
#   'minutes': '527',
#   'minutes_90s': '5.9',
#   'goals': '0',
#   'assists': '1',
#   'goals_assists': '1',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.6',
#   'npxg': '0.6',
#   'xg_assist': '0.2',
#   'npxg_xg_assist': '0.8',
#   'progressive_carries': '10',
#   'progressive_passes': '48',
#   'progressive_passes_received': '14',
#   'goals_per90': '0.00',
#   'assists_per90': '0.17',
#   'goals_assists_per90': '0.17',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.17',
#   'xg_per90': '0.11',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.14',
#   'npxg_per90': '0.11',
#   'npxg_xg_assist_per90': '0.14'},
#  {'player': 'Kieran Tierney',
#   'club': 'Arsenal',
#   'nationality': 'SCO',
#   'position': 'DF,FW',
#   'age': '27',
#   'games': '13',
#   'games_starts': '2',
#   'minutes': '259',
#   'minutes_90s': '2.9',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.4',
#   'npxg': '0.4',
#   'xg_assist': '1.4',
#   'npxg_xg_assist': '1.7',
#   'progressive_carries': '8',
#   'progressive_passes': '15',
#   'progressive_passes_received': '29',
#   'goals_per90': '0.35',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.35',
#   'goals_pens_per90': '0.35',
#   'goals_assists_pens_per90': '0.35',
#   'xg_per90': '0.12',
#   'xg_assist_per90': '0.48',
#   'xg_xg_assist_per90': '0.60',
#   'npxg_per90': '0.12',
#   'npxg_xg_assist_per90': '0.60'},
#  {'player': 'Joško Gvardiol',
#   'club': 'Manchester City',
#   'nationality': 'CRO',
#   'position': 'DF',
#   'age': '22',
#   'games': '37',
#   'games_starts': '36',
#   'minutes': '3277',
#   'minutes_90s': '36.4',
#   'goals': '5',
#   'assists': '0',
#   'goals_assists': '5',
#   'goals_pens': '5',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '4.6',
#   'npxg': '4.3',
#   'xg_assist': '2.1',
#   'npxg_xg_assist': '6.3',
#   'progressive_carries': '91',
#   'progressive_passes': '264',
#   'progressive_passes_received': '121',
#   'goals_per90': '0.14',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.14',
#   'goals_pens_per90': '0.14',
#   'goals_assists_pens_per90': '0.14',
#   'xg_per90': '0.13',
#   'xg_assist_per90': '0.06',
#   'xg_xg_assist_per90': '0.18',
#   'npxg_per90': '0.12',
#   'npxg_xg_assist_per90': '0.17'},
#  {'player': 'Erling Haaland',
#   'club': 'Manchester City',
#   'nationality': 'NOR',
#   'position': 'FW',
#   'age': '24',
#   'games': '31',
#   'games_starts': '31',
#   'minutes': '2736',
#   'minutes_90s': '30.4',
#   'goals': '22',
#   'assists': '3',
#   'goals_assists': '25',
#   'goals_pens': '19',
#   'pens_made': '3',
#   'pens_att': '4',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '22.0',
#   'npxg': '18.8',
#   'xg_assist': '3.0',
#   'npxg_xg_assist': '21.8',
#   'progressive_carries': '24',
#   'progressive_passes': '20',
#   'progressive_passes_received': '124',
#   'goals_per90': '0.72',
#   'assists_per90': '0.10',
#   'goals_assists_per90': '0.82',
#   'goals_pens_per90': '0.62',
#   'goals_assists_pens_per90': '0.72',
#   'xg_per90': '0.72',
#   'xg_assist_per90': '0.10',
#   'xg_xg_assist_per90': '0.82',
#   'npxg_per90': '0.62',
#   'npxg_xg_assist_per90': '0.72'},
#  {'player': 'Bernardo Silva',
#   'club': 'Manchester City',
#   'nationality': 'POR',
#   'position': 'MF,FW',
#   'age': '29',
#   'games': '33',
#   'games_starts': '29',
#   'minutes': '2670',
#   'minutes_90s': '29.7',
#   'goals': '4',
#   'assists': '4',
#   'goals_assists': '8',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '7',
#   'cards_red': '0',
#   'xg': '3.9',
#   'npxg': '3.9',
#   'xg_assist': '5.1',
#   'npxg_xg_assist': '9.0',
#   'progressive_carries': '101',
#   'progressive_passes': '134',
#   'progressive_passes_received': '200',
#   'goals_per90': '0.13',
#   'assists_per90': '0.13',
#   'goals_assists_per90': '0.27',
#   'goals_pens_per90': '0.13',
#   'goals_assists_pens_per90': '0.27',
#   'xg_per90': '0.13',
#   'xg_assist_per90': '0.17',
#   'xg_xg_assist_per90': '0.30',
#   'npxg_per90': '0.13',
#   'npxg_xg_assist_per90': '0.30'},
#  {'player': 'Ederson',
#   'club': 'Manchester City',
#   'nationality': 'BRA',
#   'position': 'GK',
#   'age': '30',
#   'games': '26',
#   'games_starts': '26',
#   'minutes': '2320',
#   'minutes_90s': '25.8',
#   'goals': '0',
#   'assists': '4',
#   'goals_assists': '4',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '1.5',
#   'npxg_xg_assist': '1.5',
#   'progressive_carries': '0',
#   'progressive_passes': '2',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.16',
#   'goals_assists_per90': '0.16',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.16',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.06',
#   'xg_xg_assist_per90': '0.06',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.06'},
#  {'player': 'Rúben Dias',
#   'club': 'Manchester City',
#   'nationality': 'POR',
#   'position': 'DF',
#   'age': '27',
#   'games': '27',
#   'games_starts': '25',
#   'minutes': '2271',
#   'minutes_90s': '25.2',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '1.5',
#   'npxg': '1.5',
#   'xg_assist': '0.3',
#   'npxg_xg_assist': '1.8',
#   'progressive_carries': '43',
#   'progressive_passes': '160',
#   'progressive_passes_received': '8',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.06',
#   'xg_assist_per90': '0.01',
#   'xg_xg_assist_per90': '0.07',
#   'npxg_per90': '0.06',
#   'npxg_xg_assist_per90': '0.07'},
#  {'player': 'İlkay Gündoğan',
#   'club': 'Manchester City',
#   'nationality': 'GER',
#   'position': 'MF',
#   'age': '33',
#   'games': '33',
#   'games_starts': '25',
#   'minutes': '2223',
#   'minutes_90s': '24.7',
#   'goals': '1',
#   'assists': '6',
#   'goals_assists': '7',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '3.2',
#   'npxg': '3.2',
#   'xg_assist': '3.5',
#   'npxg_xg_assist': '6.7',
#   'progressive_carries': '64',
#   'progressive_passes': '127',
#   'progressive_passes_received': '96',
#   'goals_per90': '0.04',
#   'assists_per90': '0.24',
#   'goals_assists_per90': '0.28',
#   'goals_pens_per90': '0.04',
#   'goals_assists_pens_per90': '0.28',
#   'xg_per90': '0.13',
#   'xg_assist_per90': '0.14',
#   'xg_xg_assist_per90': '0.27',
#   'npxg_per90': '0.13',
#   'npxg_xg_assist_per90': '0.27'},
#  {'player': 'Mateo Kovačić',
#   'club': 'Manchester City',
#   'nationality': 'CRO',
#   'position': 'MF',
#   'age': '30',
#   'games': '31',
#   'games_starts': '25',
#   'minutes': '2198',
#   'minutes_90s': '24.4',
#   'goals': '6',
#   'assists': '2',
#   'goals_assists': '8',
#   'goals_pens': '6',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '1',
#   'xg': '1.9',
#   'npxg': '1.9',
#   'xg_assist': '3.6',
#   'npxg_xg_assist': '5.5',
#   'progressive_carries': '56',
#   'progressive_passes': '164',
#   'progressive_passes_received': '16',
#   'goals_per90': '0.25',
#   'assists_per90': '0.08',
#   'goals_assists_per90': '0.33',
#   'goals_pens_per90': '0.25',
#   'goals_assists_pens_per90': '0.33',
#   'xg_per90': '0.08',
#   'xg_assist_per90': '0.15',
#   'xg_xg_assist_per90': '0.23',
#   'npxg_per90': '0.08',
#   'npxg_xg_assist_per90': '0.23'},
#  {'player': 'Manuel Akanji',
#   'club': 'Manchester City',
#   'nationality': 'SUI',
#   'position': 'DF',
#   'age': '29',
#   'games': '26',
#   'games_starts': '23',
#   'minutes': '2014',
#   'minutes_90s': '22.4',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '0',
#   'xg': '1.6',
#   'npxg': '1.6',
#   'xg_assist': '0.4',
#   'npxg_xg_assist': '1.9',
#   'progressive_carries': '46',
#   'progressive_passes': '158',
#   'progressive_passes_received': '7',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.09',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.09'},
#  {'player': 'Rico Lewis',
#   'club': 'Manchester City',
#   'nationality': 'ENG',
#   'position': 'DF,MF',
#   'age': '19',
#   'games': '28',
#   'games_starts': '21',
#   'minutes': '1893',
#   'minutes_90s': '21.0',
#   'goals': '1',
#   'assists': '2',
#   'goals_assists': '3',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '5',
#   'cards_red': '1',
#   'xg': '1.4',
#   'npxg': '1.4',
#   'xg_assist': '0.3',
#   'npxg_xg_assist': '1.7',
#   'progressive_carries': '39',
#   'progressive_passes': '107',
#   'progressive_passes_received': '78',
#   'goals_per90': '0.05',
#   'assists_per90': '0.10',
#   'goals_assists_per90': '0.14',
#   'goals_pens_per90': '0.05',
#   'goals_assists_pens_per90': '0.14',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Sávio',
#   'club': 'Manchester City',
#   'nationality': 'BRA',
#   'position': 'FW,MF',
#   'age': '20',
#   'games': '29',
#   'games_starts': '21',
#   'minutes': '1766',
#   'minutes_90s': '19.6',
#   'goals': '1',
#   'assists': '8',
#   'goals_assists': '9',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '3',
#   'cards_red': '0',
#   'xg': '5.0',
#   'npxg': '5.0',
#   'xg_assist': '6.9',
#   'npxg_xg_assist': '11.9',
#   'progressive_carries': '137',
#   'progressive_passes': '67',
#   'progressive_passes_received': '246',
#   'goals_per90': '0.05',
#   'assists_per90': '0.41',
#   'goals_assists_per90': '0.46',
#   'goals_pens_per90': '0.05',
#   'goals_assists_pens_per90': '0.46',
#   'xg_per90': '0.26',
#   'xg_assist_per90': '0.35',
#   'xg_xg_assist_per90': '0.61',
#   'npxg_per90': '0.26',
#   'npxg_xg_assist_per90': '0.61'},
#  {'player': 'Phil Foden',
#   'club': 'Manchester City',
#   'nationality': 'ENG',
#   'position': 'MF,FW',
#   'age': '24',
#   'games': '28',
#   'games_starts': '20',
#   'minutes': '1777',
#   'minutes_90s': '19.7',
#   'goals': '7',
#   'assists': '2',
#   'goals_assists': '9',
#   'goals_pens': '7',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '5.2',
#   'npxg': '5.2',
#   'xg_assist': '4.8',
#   'npxg_xg_assist': '9.9',
#   'progressive_carries': '50',
#   'progressive_passes': '103',
#   'progressive_passes_received': '128',
#   'goals_per90': '0.35',
#   'assists_per90': '0.10',
#   'goals_assists_per90': '0.46',
#   'goals_pens_per90': '0.35',
#   'goals_assists_pens_per90': '0.46',
#   'xg_per90': '0.26',
#   'xg_assist_per90': '0.24',
#   'xg_xg_assist_per90': '0.50',
#   'npxg_per90': '0.26',
#   'npxg_xg_assist_per90': '0.50'},
#  {'player': 'Kevin De Bruyne',
#   'club': 'Manchester City',
#   'nationality': 'BEL',
#   'position': 'MF,FW',
#   'age': '33',
#   'games': '28',
#   'games_starts': '19',
#   'minutes': '1702',
#   'minutes_90s': '18.9',
#   'goals': '4',
#   'assists': '7',
#   'goals_assists': '11',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '5.1',
#   'npxg': '5.1',
#   'xg_assist': '8.0',
#   'npxg_xg_assist': '13.1',
#   'progressive_carries': '51',
#   'progressive_passes': '157',
#   'progressive_passes_received': '150',
#   'goals_per90': '0.21',
#   'assists_per90': '0.37',
#   'goals_assists_per90': '0.58',
#   'goals_pens_per90': '0.21',
#   'goals_assists_pens_per90': '0.58',
#   'xg_per90': '0.27',
#   'xg_assist_per90': '0.42',
#   'xg_xg_assist_per90': '0.69',
#   'npxg_per90': '0.27',
#   'npxg_xg_assist_per90': '0.69'},
#  {'player': 'Matheus Nunes',
#   'club': 'Manchester City',
#   'nationality': 'POR',
#   'position': 'DF,MF',
#   'age': '25',
#   'games': '26',
#   'games_starts': '19',
#   'minutes': '1674',
#   'minutes_90s': '18.6',
#   'goals': '1',
#   'assists': '6',
#   'goals_assists': '7',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '1.2',
#   'npxg': '1.2',
#   'xg_assist': '4.4',
#   'npxg_xg_assist': '5.6',
#   'progressive_carries': '63',
#   'progressive_passes': '79',
#   'progressive_passes_received': '175',
#   'goals_per90': '0.05',
#   'assists_per90': '0.32',
#   'goals_assists_per90': '0.38',
#   'goals_pens_per90': '0.05',
#   'goals_assists_pens_per90': '0.38',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.23',
#   'xg_xg_assist_per90': '0.30',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.30'},
#  {'player': 'Jeremy Doku',
#   'club': 'Manchester City',
#   'nationality': 'BEL',
#   'position': 'FW,MF',
#   'age': '22',
#   'games': '29',
#   'games_starts': '16',
#   'minutes': '1516',
#   'minutes_90s': '16.8',
#   'goals': '3',
#   'assists': '6',
#   'goals_assists': '9',
#   'goals_pens': '3',
# ...
#   'xg_per90': '0.10',
#   'xg_assist_per90': '0.06',
#   'xg_xg_assist_per90': '0.16',
#   'npxg_per90': '0.10',
#   'npxg_xg_assist_per90': '0.16'},
#  {'player': 'Jack Stephens',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '30',
#   'games': '19',
#   'games_starts': '17',
#   'minutes': '1389',
#   'minutes_90s': '15.4',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '2',
#   'xg': '0.6',
#   'npxg': '0.6',
#   'xg_assist': '0.2',
#   'npxg_xg_assist': '0.7',
#   'progressive_carries': '14',
#   'progressive_passes': '63',
#   'progressive_passes_received': '2',
#   'goals_per90': '0.06',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.06',
#   'goals_pens_per90': '0.06',
#   'goals_assists_pens_per90': '0.06',
#   'xg_per90': '0.04',
#   'xg_assist_per90': '0.01',
#   'xg_xg_assist_per90': '0.05',
#   'npxg_per90': '0.04',
#   'npxg_xg_assist_per90': '0.05'},
#  {'player': 'Yukinari Sugawara',
#   'club': 'Southampton',
#   'nationality': 'JPN',
#   'position': 'DF,MF',
#   'age': '24',
#   'games': '30',
#   'games_starts': '16',
#   'minutes': '1557',
#   'minutes_90s': '17.3',
#   'goals': '1',
#   'assists': '1',
#   'goals_assists': '2',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '0.5',
#   'npxg': '0.5',
#   'xg_assist': '2.2',
#   'npxg_xg_assist': '2.7',
#   'progressive_carries': '33',
#   'progressive_passes': '72',
#   'progressive_passes_received': '78',
#   'goals_per90': '0.06',
#   'assists_per90': '0.06',
#   'goals_assists_per90': '0.12',
#   'goals_pens_per90': '0.06',
#   'goals_assists_pens_per90': '0.12',
#   'xg_per90': '0.03',
#   'xg_assist_per90': '0.13',
#   'xg_xg_assist_per90': '0.16',
#   'npxg_per90': '0.03',
#   'npxg_xg_assist_per90': '0.16'},
#  {'player': 'Adam Armstrong',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'FW,MF',
#   'age': '27',
#   'games': '20',
#   'games_starts': '15',
#   'minutes': '1248',
#   'minutes_90s': '13.9',
#   'goals': '2',
#   'assists': '2',
#   'goals_assists': '4',
#   'goals_pens': '2',
#   'pens_made': '0',
#   'pens_att': '1',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '3.3',
#   'npxg': '2.3',
#   'xg_assist': '1.2',
#   'npxg_xg_assist': '3.5',
#   'progressive_carries': '25',
#   'progressive_passes': '21',
#   'progressive_passes_received': '79',
#   'goals_per90': '0.14',
#   'assists_per90': '0.14',
#   'goals_assists_per90': '0.29',
#   'goals_pens_per90': '0.14',
#   'goals_assists_pens_per90': '0.29',
#   'xg_per90': '0.24',
#   'xg_assist_per90': '0.09',
#   'xg_xg_assist_per90': '0.32',
#   'npxg_per90': '0.17',
#   'npxg_xg_assist_per90': '0.25'},
#  {'player': 'Cameron Archer',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'FW',
#   'age': '23',
#   'games': '35',
#   'games_starts': '13',
#   'minutes': '1441',
#   'minutes_90s': '16.0',
#   'goals': '2',
#   'assists': '0',
#   'goals_assists': '2',
#   'goals_pens': '2',
#   'pens_made': '0',
#   'pens_att': '1',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '5.7',
#   'npxg': '4.9',
#   'xg_assist': '0.5',
#   'npxg_xg_assist': '5.4',
#   'progressive_carries': '22',
#   'progressive_passes': '14',
#   'progressive_passes_received': '66',
#   'goals_per90': '0.12',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.12',
#   'goals_pens_per90': '0.12',
#   'goals_assists_pens_per90': '0.12',
#   'xg_per90': '0.36',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.39',
#   'npxg_per90': '0.31',
#   'npxg_xg_assist_per90': '0.34'},
#  {'player': 'James Bree',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '26',
#   'games': '17',
#   'games_starts': '13',
#   'minutes': '1075',
#   'minutes_90s': '11.9',
#   'goals': '0',
#   'assists': '1',
#   'goals_assists': '1',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.1',
#   'npxg': '0.1',
#   'xg_assist': '0.9',
#   'npxg_xg_assist': '1.0',
#   'progressive_carries': '13',
#   'progressive_passes': '34',
#   'progressive_passes_received': '43',
#   'goals_per90': '0.00',
#   'assists_per90': '0.08',
#   'goals_assists_per90': '0.08',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.08',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.08',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Paul Onuachu',
#   'club': 'Southampton',
#   'nationality': 'NGA',
#   'position': 'FW',
#   'age': '30',
#   'games': '25',
#   'games_starts': '11',
#   'minutes': '1050',
#   'minutes_90s': '11.7',
#   'goals': '4',
#   'assists': '1',
#   'goals_assists': '5',
#   'goals_pens': '4',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '3.6',
#   'npxg': '3.6',
#   'xg_assist': '0.5',
#   'npxg_xg_assist': '4.1',
#   'progressive_carries': '7',
#   'progressive_passes': '13',
#   'progressive_passes_received': '40',
#   'goals_per90': '0.34',
#   'assists_per90': '0.09',
#   'goals_assists_per90': '0.43',
#   'goals_pens_per90': '0.34',
#   'goals_assists_pens_per90': '0.43',
#   'xg_per90': '0.31',
#   'xg_assist_per90': '0.04',
#   'xg_xg_assist_per90': '0.35',
#   'npxg_per90': '0.31',
#   'npxg_xg_assist_per90': '0.35'},
#  {'player': 'Nathan Wood-Gordon',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '22',
#   'games': '11',
#   'games_starts': '9',
#   'minutes': '773',
#   'minutes_90s': '8.6',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '2',
#   'cards_red': '0',
#   'xg': '0.2',
#   'npxg': '0.2',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.3',
#   'progressive_carries': '2',
#   'progressive_passes': '17',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.03',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.03',
#   'npxg_per90': '0.03',
#   'npxg_xg_assist_per90': '0.03'},
#  {'player': 'William Smallbone',
#   'club': 'Southampton',
#   'nationality': 'IRL',
#   'position': 'MF',
#   'age': '24',
#   'games': '18',
#   'games_starts': '6',
#   'minutes': '690',
#   'minutes_90s': '7.7',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.6',
#   'npxg': '0.6',
#   'xg_assist': '0.7',
#   'npxg_xg_assist': '1.3',
#   'progressive_carries': '5',
#   'progressive_passes': '27',
#   'progressive_passes_received': '25',
#   'goals_per90': '0.13',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.13',
#   'goals_pens_per90': '0.13',
#   'goals_assists_pens_per90': '0.13',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.10',
#   'xg_xg_assist_per90': '0.17',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.17'},
#  {'player': 'Welington',
#   'club': 'Southampton',
#   'nationality': 'BRA',
#   'position': 'DF',
#   'age': '23',
#   'games': '10',
#   'games_starts': '6',
#   'minutes': '482',
#   'minutes_90s': '5.4',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.1',
#   'progressive_carries': '5',
#   'progressive_passes': '11',
#   'progressive_passes_received': '19',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.01',
#   'xg_xg_assist_per90': '0.02',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.02'},
#  {'player': 'Alex McCarthy',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'GK',
#   'age': '34',
#   'games': '5',
#   'games_starts': '5',
#   'minutes': '450',
#   'minutes_90s': '5.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.0',
#   'progressive_carries': '0',
#   'progressive_passes': '0',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.00',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.00'},
#  {'player': 'Adam Lallana',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'MF',
#   'age': '36',
#   'games': '14',
#   'games_starts': '5',
#   'minutes': '361',
#   'minutes_90s': '4.0',
#   'goals': '0',
#   'assists': '2',
#   'goals_assists': '2',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '4',
#   'cards_red': '0',
#   'xg': '0.2',
#   'npxg': '0.2',
#   'xg_assist': '0.9',
#   'npxg_xg_assist': '1.1',
#   'progressive_carries': '6',
#   'progressive_passes': '24',
#   'progressive_passes_received': '10',
#   'goals_per90': '0.00',
#   'assists_per90': '0.50',
#   'goals_assists_per90': '0.50',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.50',
#   'xg_per90': '0.04',
#   'xg_assist_per90': '0.23',
#   'xg_xg_assist_per90': '0.27',
#   'npxg_per90': '0.04',
#   'npxg_xg_assist_per90': '0.27'},
#  {'player': 'Ben Brereton',
#   'club': 'Southampton',
#   'nationality': 'CHI',
#   'position': 'FW',
#   'age': '25',
#   'games': '10',
#   'games_starts': '4',
#   'minutes': '449',
#   'minutes_90s': '5.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.9',
#   'npxg': '0.9',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '1.0',
#   'progressive_carries': '12',
#   'progressive_passes': '9',
#   'progressive_passes_received': '42',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.18',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.20',
#   'npxg_per90': '0.18',
#   'npxg_xg_assist_per90': '0.20'},
#  {'player': 'Ross Stewart',
#   'club': 'Southampton',
#   'nationality': 'SCO',
#   'position': 'FW',
#   'age': '28',
#   'games': '12',
#   'games_starts': '4',
#   'minutes': '389',
#   'minutes_90s': '4.3',
#   'goals': '1',
#   'assists': '0',
#   'goals_assists': '1',
#   'goals_pens': '1',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '1.1',
#   'npxg': '1.1',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '1.1',
#   'progressive_carries': '3',
#   'progressive_passes': '2',
#   'progressive_passes_received': '10',
#   'goals_per90': '0.23',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.23',
#   'goals_pens_per90': '0.23',
#   'goals_assists_pens_per90': '0.23',
#   'xg_per90': '0.25',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.25',
#   'npxg_per90': '0.25',
#   'npxg_xg_assist_per90': '0.25'},
#  {'player': 'Ryan Fraser',
#   'club': 'Southampton',
#   'nationality': 'SCO',
#   'position': 'FW,DF',
#   'age': '30',
#   'games': '8',
#   'games_starts': '4',
#   'minutes': '306',
#   'minutes_90s': '3.4',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '1',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.1',
#   'progressive_carries': '10',
#   'progressive_passes': '8',
#   'progressive_passes_received': '18',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.01',
#   'xg_assist_per90': '0.03',
#   'xg_xg_assist_per90': '0.04',
#   'npxg_per90': '0.01',
#   'npxg_xg_assist_per90': '0.04'},
#  {'player': 'Charlie Taylor',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'DF',
#   'age': '30',
#   'games': '8',
#   'games_starts': '3',
#   'minutes': '356',
#   'minutes_90s': '4.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '1',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.1',
#   'npxg_xg_assist': '0.1',
#   'progressive_carries': '3',
#   'progressive_passes': '9',
#   'progressive_passes_received': '7',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.02',
#   'xg_xg_assist_per90': '0.02',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.02'},
#  {'player': 'Joe Lumley',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'GK',
#   'age': '29',
#   'games': '3',
#   'games_starts': '3',
#   'minutes': '270',
#   'minutes_90s': '3.0',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.0',
#   'progressive_carries': '0',
#   'progressive_passes': '0',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.00',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.00',
#   'npxg_per90': '0.00',
#   'npxg_xg_assist_per90': '0.00'},
#  {'player': 'Armel Bella Kotchap',
#   'club': 'Southampton',
#   'nationality': 'GER',
#   'position': 'DF',
#   'age': '22',
#   'games': '4',
#   'games_starts': '2',
#   'minutes': '331',
#   'minutes_90s': '3.7',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.3',
#   'npxg': '0.3',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.3',
#   'progressive_carries': '0',
#   'progressive_passes': '5',
#   'progressive_passes_received': '0',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.09',
#   'xg_assist_per90': '0.00',
#   'xg_xg_assist_per90': '0.09',
#   'npxg_per90': '0.09',
#   'npxg_xg_assist_per90': '0.09'},
#  {'player': 'Albert Grønbaek',
#   'club': 'Southampton',
#   'nationality': 'DEN',
#   'position': 'FW,MF',
#   'age': '23',
#   'games': '4',
#   'games_starts': '2',
#   'minutes': '143',
#   'minutes_90s': '1.6',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.1',
#   'npxg': '0.1',
#   'xg_assist': '0.0',
#   'npxg_xg_assist': '0.1',
#   'progressive_carries': '1',
#   'progressive_passes': '1',
#   'progressive_passes_received': '3',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.07',
#   'xg_assist_per90': '0.01',
#   'xg_xg_assist_per90': '0.08',
#   'npxg_per90': '0.07',
#   'npxg_xg_assist_per90': '0.08'},
#  {'player': 'Jay Robinson',
#   'club': 'Southampton',
#   'nationality': 'ENG',
#   'position': 'MF,FW',
#   'age': '17',
#   'games': '4',
#   'games_starts': '1',
#   'minutes': '137',
#   'minutes_90s': '1.5',
#   'goals': '0',
#   'assists': '0',
#   'goals_assists': '0',
#   'goals_pens': '0',
#   'pens_made': '0',
#   'pens_att': '0',
#   'cards_yellow': '0',
#   'cards_red': '0',
#   'xg': '0.0',
#   'npxg': '0.0',
#   'xg_assist': '0.7',
#   'npxg_xg_assist': '0.7',
#   'progressive_carries': '3',
#   'progressive_passes': '1',
#   'progressive_passes_received': '10',
#   'goals_per90': '0.00',
#   'assists_per90': '0.00',
#   'goals_assists_per90': '0.00',
#   'goals_pens_per90': '0.00',
#   'goals_assists_pens_per90': '0.00',
#   'xg_per90': '0.03',
#   'xg_assist_per90': '0.44',
#   'xg_xg_assist_per90': '0.47',
#   'npxg_per90': '0.03',
#   'npxg_xg_assist_per90': '0.47'}]

# %%
df = pd.DataFrame(players)

df = df.apply(pd.to_numeric, errors='ignore')

type_map = {
    "object": "TEXT",
    "int64": "INTEGER",
    "float64": "REAL"
}

columns_sql = []
for col, dtype in df.dtypes.items():
    sql_type = type_map.get(str(dtype), "TEXT")
    columns_sql.append(f'{col} {sql_type}')

columns_def = ", ".join(columns_sql)

create_table_sql = f'CREATE TABLE IF NOT EXISTS players ({columns_def})'

print(create_table_sql)

conn = sqlite3.connect("players.db")
cursor = conn.cursor()

cursor.execute("DROP TABLE IF EXISTS players")

cursor.execute(create_table_sql)
conn.commit()

df.to_sql("players", conn, if_exists='append', index=False)

conn.close()
# Out:
# CREATE TABLE IF NOT EXISTS players (player TEXT, club TEXT, nationality TEXT, position TEXT, age INTEGER, games INTEGER, games_starts INTEGER, minutes INTEGER, minutes_90s REAL, goals INTEGER, assists INTEGER, goals_assists INTEGER, goals_pens INTEGER, pens_made INTEGER, pens_att INTEGER, cards_yellow INTEGER, cards_red INTEGER, xg REAL, npxg REAL, xg_assist REAL, npxg_xg_assist REAL, progressive_carries INTEGER, progressive_passes INTEGER, progressive_passes_received INTEGER, goals_per90 REAL, assists_per90 REAL, goals_assists_per90 REAL, goals_pens_per90 REAL, goals_assists_pens_per90 REAL, xg_per90 REAL, xg_assist_per90 REAL, xg_xg_assist_per90 REAL, npxg_per90 REAL, npxg_xg_assist_per90 REAL)
# C:\Users\ducki\AppData\Local\Temp\ipykernel_24148\2628237157.py:3: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors='ignore')
